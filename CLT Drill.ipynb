# %%
import numpy as np
import pandas as pd
import scipy
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pop1 = np.random.binomial(10, 0.2, 10000)
pop2 = np.random.binomial(10,0.5, 10000) 
plt.hist(pop1, alpha=0.5, label='Population 1') 
plt.hist(pop2, alpha=0.5, label='Population 2') 
plt.legend(loc='upper right') 
plt.show()

# %%
sample1 = np.random.choice(pop1, 100, replace=True)
sample2 = np.random.choice(pop2, 100, replace=True)

plt.hist(sample1, alpha=.05, label='sample 1')
plt.hist(sample2, alpha=.05, label='sample 2')
plt.legend(loc='upper right')
plt.show()

# %%
print(sample1.mean())
print(sample2.mean())
print(sample1.std())
print(sample2.std())
#difference of sample means
diff = sample2.mean( ) -sample1.mean()
print(diff)
# Out:
# 2.13
# 5.04
# 1.1887388274974446
# 1.5486768546084753
# 2.91

# %%
size = np.array([len(sample1), len(sample2)])
sd = np.array([sample1.std(), sample2.std()])
diff_se = (sum(sd ** 2 / size))  ** 0.5
#t-value
print(diff/diff_se)
# Out:
# 14.905447765212022

# %%
from scipy.stats import ttest_ind
print(ttest_ind(sample2, sample1, equal_var=False))
# Out:
# Ttest_indResult(statistic=14.830733270834905, pvalue=2.486491372363706e-33)

# %%
#Expectation: since we're increasing the sample size 10 fold, I would imagine the mean may vary because it is reactive 
#to sample size.
sample1 = np.random.choice(pop1, 1000, replace=True)
sample2 = np.random.choice(pop2, 1000, replace=True)

plt.hist(sample1, alpha=.05, label='sample 1')
plt.hist(sample2, alpha=.05, label='sample 2')
plt.legend(loc='upper right')
plt.show()

# %%
print(sample1.mean())
print(sample2.mean())
print(sample1.std())
print(sample2.std())
#difference of sample means
diff = sample2.mean( ) -sample1.mean()
print(diff)
# Out:
# 2.07
# 4.915
# 1.281834622718547
# 1.5974276196435317
# 2.845

# %%
#Expectation: this is a very drastic decrease that may artificially deflate 
#the mean and std because the sample size is too small
sample1 = np.random.choice(pop1, 20, replace=True)
sample2 = np.random.choice(pop2, 20, replace=True)

plt.hist(sample1, alpha=.05, label='sample 1')
plt.hist(sample2, alpha=.05, label='sample 2')
plt.legend(loc='upper right')
plt.show()
print(sample1.mean())
print(sample2.mean())
print(sample1.std())
print(sample2.std())
#difference of sample means
diff = sample2.mean( ) -sample1.mean()
print(diff)
# Out:
# 1.6
# 5.3
# 0.9695359714832659
# 1.3453624047073711
# 3.6999999999999997

# %%
pop1 = np.random.binomial(10, 0.3, 10000)
pop2 = np.random.binomial(10,0.5, 10000) 
plt.hist(pop1, alpha=0.5, label='Population 1') 
plt.hist(pop2, alpha=0.5, label='Population 2') 
plt.legend(loc='upper right') 
plt.show()

# %%
sample1 = np.random.choice(pop1, 100, replace=True)
sample2 = np.random.choice(pop2, 100, replace=True)

plt.hist(sample1, alpha=.05, label='sample 1')
plt.hist(sample2, alpha=.05, label='sample 2')
plt.legend(loc='upper right')
plt.show()

# %%
size = np.array([len(sample1), len(sample2)])
sd = np.array([sample1.std(), sample2.std()])
diff_se = (sum(sd ** 2 / size))  ** 0.5
#t-value
print(diff/diff_se)
from scipy.stats import ttest_ind
print(ttest_ind(sample2, sample1, equal_var=False))
# Out:
# -0.2794401410695307
# Ttest_indResult(statistic=-0.27803942978748475, pvalue=0.7814603868906019)

# %%
#The variance is decreasing and the groups are becoming tighter around the mean.
pop1 = np.random.binomial(10, 0.4, 10000)
pop2 = np.random.binomial(10,0.5, 10000) 
plt.hist(pop1, alpha=0.5, label='Population 1') 
plt.hist(pop2, alpha=0.5, label='Population 2') 
plt.legend(loc='upper right') 
plt.show()

# %%
sample1 = np.random.choice(pop1, 100, replace=True)
sample2 = np.random.choice(pop2, 100, replace=True)

plt.hist(sample1, alpha=.05, label='sample 1')
plt.hist(sample2, alpha=.05, label='sample 2')
plt.legend(loc='upper right')
plt.show()
print(sample1.mean())
print(sample2.mean())
print(sample1.std())
print(sample2.std())
#difference of sample means
diff = sample2.mean( ) -sample1.mean()
print(diff)
# Out:
# 9.980835361633423
# 10.005605736589793
# 0.29577892662364796
# 0.10479108858474782
# 0.024770374956370134

# %%
size = np.array([len(sample1), len(sample2)])
sd = np.array([sample1.std(), sample2.std()])
diff_se = (sum(sd ** 2 / size))  ** 0.5
#t-value
print(diff/diff_se)
# Out:
# -0.2794401410695307

# %%
#different distribution
pop1 = np.random.normal(10, .3, 10000)
pop2 = np.random.normal(10, .1, 10000)
plt.hist(pop1, alpha=0.5, label='Population 1') 
plt.hist(pop2, alpha=0.5, label='Population 2') 
plt.legend(loc='upper right') 
plt.show()

# %%
#the sample means did not vary much at all, which demostrates the power of CLT
sample1 = np.random.choice(pop1, 100, replace=True)
sample2 = np.random.choice(pop2, 100, replace=True)

plt.hist(sample1, alpha=.05, label='sample 1')
plt.hist(sample2, alpha=.05, label='sample 2')
plt.legend(loc='upper right')
plt.show()
print(sample1.mean())
print(sample2.mean())
print(sample1.std())
print(sample2.std())
#difference of sample means
diff = sample2.mean( ) -sample1.mean()
print(diff)
# Out:
# 9.995652746104634
# 9.986728784856371
# 0.3034518937155749
# 0.09951026481536353
# -0.008923961248262557

# %%
size = np.array([len(sample1), len(sample2)])
sd = np.array([sample1.std(), sample2.std()])
diff_se = (sum(sd ** 2 / size))  ** 0.5
#t-value
print(diff/diff_se)
from scipy.stats import ttest_ind
print(ttest_ind(sample2, sample1, equal_var=False))
# Out:
# -0.2794401410695307
# Ttest_indResult(statistic=-0.27803942978748475, pvalue=0.7814603868906019)

# %%
#the samples reduced in variation over time, becoming tighter around the mean.  The different 
#distributions did not change the values much.
